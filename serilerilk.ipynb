# %% [markdown]
# <a href="https://colab.research.google.com/github/esrasucu/hu-bby261-2024/blob/main/serilerilk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip list

# %%
import pandas as pd
seriler = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/seriler.csv/data (2).csv', usecols=[1])

print(seriler.to_string())
# Out:
#                                                               title
# 0                                                      Breaking Bad
# 1                                                   Planet Earth II
# 2                                                  Band of Brothers
# 3                                                      Planet Earth
# 4                                                      Tree of Life
# 5                                                         Chernobyl
# 6                                                          The Wire
# 7                                        Avatar: The Last Airbender
# 8                                                 Sapne Vs Everyone
# 9                                                    Blue Planet II
# 10                                                           Cosmos
# 11                                                            Bluey
# 12                                                      BB Ki Vines
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi,200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()
